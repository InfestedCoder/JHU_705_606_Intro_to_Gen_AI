# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 72
from IPython.display import Markdown
import numpy as np
import os

MODEL_PATH= '../../models/'
os.environ['HF_HOME'] = MODEL_PATH  # before import transformers
os.environ['HF_DATASETS_OFFLINE']= '1'

# %%
import torch
import transformers
from transformers import pipeline

Device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print(f'PyTorch version= {torch.__version__}')
print(f'transformers version= {transformers.__version__}')
print(f'CUDA available= {torch.cuda.is_available()}')
# Out:
# PyTorch version= 2.10.0
# transformers version= 5.0.0
# CUDA available= False

# %%
# from huggingface_hub import login
# login()

# %%
Model = pipeline("text-generation", model="meta-llama/Llama-3.2-1B-Instruct", max_length=4096, dtype=torch.bfloat16, device=Device)
# Out:
# Loading weights: 100%|██████████| 146/146 [00:00<00:00, 1032.00it/s, Materializing param=model.norm.weight]

# %%
def query(_model, _prompt):
    messages = [{'role':'user', 'content':_prompt}]
    response = _model(messages)
    return response[0]['generated_text'][1]['content']

# %%
Markdown(query(Model, 'Who are you?'))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# I'm an artificial intelligence model known as Llama. Llama stands for "Large Language Model Meta AI."
